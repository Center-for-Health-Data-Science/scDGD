# %% [markdown]
# # Loading a pretrained scDGD for the 1 million mouse brain data
#
# Trained on 10X data. For details check the paper.

# %% [markdown]
# ### imports

# %%
import torch
import numpy as np
#!pip install anndata
import anndata as ad
#!pip install scanpy
import scanpy as sc

# install scDGD from the repository
#!pip install git+https://github.com/Center-for-Health-Data-Science/scDGD
import scDGD
from scDGD.classes import GaussianMixture
from scDGD.models import DGD

# %%
save_dir='model/'

# %%
# because of the size of the files, we had to upload them compressed
# unzip the folders here
# !unzip data_info.zip
# Out:
# Archive:  data_info.zip
#   inflating: data_obs.csv
#   inflating: __MACOSX/._data_obs.csv
#   inflating: data_var.csv

# %% [markdown]
# ### load the model

# %%
gmm = GaussianMixture.load(save_dir=save_dir)
model = DGD.load(save_dir=save_dir)

# %% [markdown]
# ### plot embedding and clustering
#
# The embedding (representation) for all cells is too large to upload to github, but you can download it from this gdrive folder:

# %%
# !wget https://drive.google.com/drive/folders/13YvenHq5sOZjfhBmPfelxtm8xlu-gwSH?usp=sharing

# %%
from scDGD.functions.analysis import plot_cluster_heatmap, plot_latent_umap
# Out:
# /Users/dbm829/Library/Python/3.9/lib/python/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/dbm829/Library/Python/3.9/lib/python/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# ...

# %%
plot_cluster_heatmap(save_dir=save_dir)

# %%
plot_latent_umap(save_dir=save_dir)
